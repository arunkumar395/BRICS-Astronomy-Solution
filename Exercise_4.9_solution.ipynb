# %% [markdown]
# Chapter 4: Variables and Data Types

# %% [markdown]
# Exercise 4.9(Variables)

# %% [markdown]
# 1.

# %%
planet_name="Jupiter"

# %%
planet_name
# Out:
# 'Jupiter'

# %% [markdown]
# 2.

# %%
Distance_to_sun="149.6 million kilometers"
Distance_to_sun
# Out:
# '149.6 million kilometers'

# %% [markdown]
# 3.

# %%
star_temp=5500
star_temp
#star_temp+=500
#star_temp
# Out:
# 5500

# %% [markdown]
# 4.

# %%
is_gas_giant=True
print("is Jupiter a gas giant?",is_gas_giant)
# Out:
# is Jupiter a gas giant? True

# %% [markdown]
# 5.

# %%
moon_count=2 
"""  An f-string (formatted string literal) in Python lets you embed variables or expressions directly inside a string by placing them in `{}` and prefixing the string with `f`, making formatting concise and readable.
It works in Python 3.6 and above, and can evaluate variables, calculations, and even function calls inside the braces at runtime.
"""
print(f"Mars has {moon_count} moons")
# Out:
# Mars has 2 moons

# %% [markdown]
# 6.

# %% [markdown]
# "Number Of Stars" fails both syntax rules (spaces not allowed) and style guidelines (not snake_case), so it’s not appropriate in Python. Use something like number_of_stars instead.

# %% [markdown]
# 7.

# %%
galaxy_type="Spiral"
galaxy_type
# Out:
# 'Spiral'

# %% [markdown]
# Exercise 4.9(Operators)

# %% [markdown]
# 1.

# %%
#define the variables in AU
Distane_earth_sun = 1.0
Distance_mars_sun = 1.52
Difference_earth_mars= Distance_mars_sun- Distane_earth_sun
print(Difference_earth_mars)
# Out:
# 0.52

# %% [markdown]
# 2.

# %%
#Jupiter's Time period in Earth years
Jupiter_orbit = 11.86
#one earth year in days
Earth_day = 365.25
#jupiter's orbit in days
Jupiter_orbit_day = Jupiter_orbit * Earth_day
print(f"Jupiter's Timpe period in days {Jupiter_orbit_day}.")
# Out:
# Jupiter's Timpe period in days 4331.865.

# %% [markdown]
# 3.

# %%
Jupiter_moons = 79
Jupiter_moons+=3
Jupiter_moons
# Out:
# 82

# %% [markdown]
# 4.

# %%
venus_temp=462
earth_temp=15
# here we use the comparison operator
venus_temp > earth_temp
# Out:
# True

# %% [markdown]
# 5.

# %%
galaxy_type="Spiral"
galaxy_type== "Elliptical"
# == → compares values
# Out:
# False

# %% [markdown]
# 6.

# %%
water = True
atmosphere_ok = False
habitable = water and atmosphere_ok
habitable
# Out:
# False

# %% [markdown]
# 7.

# %%
is_night = True
is_solar_telescope = False
observing_possible = is_night or is_solar_telescope
observing_possible
# Out:
# True

# %% [markdown]
# 8.

# %%
proxima_centauri_distance_ly = 4.24
km_per_ly = 9.461e12
distance_km = proxima_centauri_distance_ly * km_per_ly
distance_km
# Out:
# 40114640000000.0
