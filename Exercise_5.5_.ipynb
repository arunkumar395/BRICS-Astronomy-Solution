# %% [markdown]
# Exercise_5.5

# %% [markdown]
# Lists

# %% [markdown]
# 1.

# %%
plantes=["Mercury", "Venus", "Earth"]
type(plantes)
# Out:
# list

# %% [markdown]
# 2.

# %%
plantes[1]
# Out:
# 'Venus'

# %% [markdown]
# 3.

# %%
plantes.append("Mars")

# %%
plantes
# Out:
# ['Mercury', 'Venus', 'Earth', 'Mars']

# %% [markdown]
# 4.

# %%
moons=["Moon", "Phobos", "Deimos"]

# %%
print(len(moons))
moons.count("Moon")
# Out:
# 3
# 1

# %% [markdown]
# Dictionaries

# %% [markdown]
# 5.

# %%
star={"name": "Sun"}
type(star)
# Out:
# dict

# %% [markdown]
# 6.

# %%
star_info = {'name': "Sirius",
             'color': "Blue-White",
            }
star_info.get("color")
# Out:
# 'Blue-White'

# %% [markdown]
# 7.

# %%
star_info.update({"distance": "8.6 light-years"})
star_info
# Out:
# {'name': 'Sirius', 'color': 'Blue-White', 'distance': '8.6 light-years'}

# %%
# Out:
# {'name': 'Sirius', 'color': 'Blue-White', 'distance': '8.6 light-years'}

# %% [markdown]
# 8.

# %%
galaxy_info = {'name': "Andromeda", 'type': "Spiral"}
galaxy_info.keys()
# Out:
# dict_keys(['name', 'type'])

# %% [markdown]
# Tuples

# %% [markdown]
# 9.

# %%
data=("Gagarin", 1961)

# %%
type(data)
# Out:
# tuple

# %% [markdown]
# 10.

# %%
moon_info = (1969, "Armstrong")

# %%
moon_info[0]
# Out:
# 1969

# %% [markdown]
# 11.

# %%
"NO, tuples are immutable data types. They cannot be changed"

# %% [markdown]
# Sets

# %% [markdown]
# 12.

# %%
gas_planets = {"Jupiter", "Saturn", "Uranus", "Neptune"}
type(gas_planets)
# Out:
# set

# %% [markdown]
# 13.

# %%
"Earth" in gas_planets
# Out:
# False

# %% [markdown]
# 14.

# %%
gas_planets.add("Jupiter")

# %%
gas_planets # No changes because of sets have the unique values"
# Out:
# {'Jupiter', 'Neptune', 'Saturn', 'Uranus'}

# %% [markdown]
# 15.

# %%
observed=["Moon", "Mars", "Moon", "Jupiter", "Mars"]
observed
# Out:
# ['Moon', 'Mars', 'Moon', 'Jupiter', 'Mars']

# %%
unique_planets=set(observed)

# %%
unique_planets
# Out:
# {'Jupiter', 'Mars', 'Moon'}

# %% [markdown]
# For more on python data structures, see https://docs.python.org/3/tutorial/
# datastructures.html.
